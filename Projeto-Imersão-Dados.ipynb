# %% [markdown]
# # Dia 1

# %% [markdown]
# ## 1. Importando os dados

# %%
import pandas as pd

#url_dados = "https://github.com/gabicgama/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
path ='dados/dados_experimentos.csv'
df = pd.read_csv(path)
df
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
#head() exibe as 5 primeiras linhas
df.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
# shape retorna o total de linhas x colunas do dataframe
df.shape
# Out:
# (23814, 877)

# %%
df['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# ## 2. Obtendo os valores únicos

# %% [markdown]
# Método ```unique()``` retorna todos os valores únicos de uma dada coluna.

# %%
df['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
df['tempo'].unique()
# Out:
# array([24, 72, 48], dtype=int64)

# %%
df['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# ## 3. Obtendo o total de cada classe de dados

# %% [markdown]
# Método ```value_counts()``` retorna a quantidade total de cada valor de uma determinada coluna.

# %%
df['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
df['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# ## 4. Plotando gráficos

# %%
df['tratamento'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='tratamento'>

# %%
df['tempo'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Filtrando dados

# %%
# ao se fazer: dados['g-0' > 0], terá como retorno uma série de True ou Falso
df_filtrado = df[df['g-0'] > 0]
df_filtrado
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 6      id_001bd861f     com_droga     24   D2  746ca1f5a  2.0440  1.7000
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# ...             ...           ...    ...  ...        ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23808  id_fff8c2444     com_droga     72   D1  6c3a459be  0.1608 -1.0500
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
 len(df[df['tratamento'] == "com_droga"])
# Out:
# 21948

# %%
df.groupby(['dose','tratamento'])[('tempo')].value_counts()
# Out:
# dose  tratamento    tempo
# D1    com_controle  48        343
#                     72        307
#                     24        301
#       com_droga     48       4011
#                     72       3600
#                     24       3585
# D2    com_controle  24        305
#                     48        305
#                     72        305
#       com_droga     48       3591
#                     24       3581
#                     72       3580
# Name: tempo, dtype: int64

# %% [markdown]
# <h1 style="text-align:center">DESAFIOS</h1>

# %% [markdown]
# ### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %%
#valores únicos
df['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#quantidade de casos para cada valor
df['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Dependendo o tipo de pesquisa é possível usar o mesmo controle para mais de um caso. Repare que o grupo de controle é um grupo onde não estamos aplicando o efeito de uma determinada droga. Então, esse mesmo grupo pode ser utilizado como controle para cada uma das drogas estudadas.
# <br>Um ponto relevante da base de dados que estamos trabalhando é que todos os dados de controle estão relacionados ao estudo de apenas uma droga.

# %%
print(f"Total de dados: {len(df['id'])}\n")
print(f"Quantidade de drogas: {len(df.groupby(['droga', 'tratamento']).count()['id'])}\n")
display(df.query('tratamento == "com_controle"').value_counts('droga'))
print()
display(df.query('droga == "cacb2b860"').value_counts('tratamento'))
print()
# Out:
# Total de dados 23814
#
# Quantidade de drogas 3289
# droga
# cacb2b860    1866
# dtype: int64
# tratamento
# com_controle    1866
# dtype: int64

# %% [markdown]
# ### Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
# Sobre o método tail():
# Pode-se especificar a quantidade de últimos valores n que são exibidos;
# tail(3) -> retornará os 3 últimos valores;
# tail(-n) -> para valor negativo, o método retorna todos os valores, execeto os n valores que foram passado por parâmetro.

df.tail()
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# ### Desafio 03: Proporção das classes tratamento

# %%
df['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ### Desafio 04: Quantos tipos de drogas foram investigados

# %%
# com value_counts() exibe o total de drogas em 'Length'
df['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 5cc5a5a19       1
# 547f80a41       1
# fb69fd749       1
# c5ffd58ca       1
# 32dccc366       1
# Name: droga, Length: 3289, dtype: int64

# %%
# com o 'value_counts().size' conseguimos retornar o tamanho/quantidade de drogas
df['droga'].value_counts().size
# Out:
# 3289

# %%
# uma outra forma de exibir o total de drogas, é com o método 'describe()'
df['droga'].describe()
# Out:
# count         23814
# unique         3289
# top       cacb2b860
# freq           1866
# Name: droga, dtype: object

# %%
len(df['droga'].unique())
# Out:
# 3289

# %%
df['droga'].value_counts().shape[0]
# Out:
# 3289

# %% [markdown]
# ### Desafio 05: Procurar na documentação o método query(pandas)

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
df.query('`g-0` > 0')
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 6      id_001bd861f     com_droga     24   D2  746ca1f5a  2.0440  1.7000
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# ...             ...           ...    ...  ...        ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23808  id_fff8c2444     com_droga     72   D1  6c3a459be  0.1608 -1.0500
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %% [markdown]
# ### Desafio 06: Renomear as colunas tirando o hífen

# %%
df.columns = [col.replace('-','') for col in df.columns]
df.head()
# outra forma de fazer replace: 
# df.columns = df.columns.str.replace('-','')
# Out:
#              id tratamento  tempo dose   composto      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ### Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(df['tratamento'].unique(),df['tratamento'].value_counts(), color ='#ffa381')
plt.title('Tipos de tratamento', fontsize=20)
plt.xlabel("tratamento", fontsize=14)
plt.ylabel("count", fontsize=14)
plt.show()

# %%
valor_tratamento = df['tratamento'].value_counts(ascending=True)
ax = valor_tratamento.sort_index().plot.bar(color = 'green')
ax.set_title('Tipos de tratamento', fontsize = 20, color ='darkblue')
ax.set_xlabel('Tratamento', fontsize = 14)
ax.set_ylabel('Quantidade', fontsize = 14)
plt.xticks(rotation = 0, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
plt.title('Tempos aplicados', size=20)
sns.countplot(data=df,x='tempo', palette ='pastel');

# %% [markdown]
# ### Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Se quiser mais informações a base dados estudada na imersão é uma versão simplificada [deste desafio](https://www.kaggle.com/c/lish-moa/overview/description) do Kaggle (em inglês).

# %% [markdown]
# # Dia 2

# %% [markdown]
# ## 1. Renomeando a coluna 'droga' para 'composto'

# %% [markdown]
# Utilizando o método ``rename()``, e passando como parâmetro a coluna que foi mapeada através de um dicionário, podemos renomear o nome de uma coluna. Outro parâmetro ``implace=True`` faz com que a coluna seja renomeada no local, diretamente no dataframe. Caso esse parâmetro não seja declarado, o default é ``inplace = False`` e o retorno será uma cópia do objeto.

# %%
map_ = {'droga':'composto'}
df.rename(columns=map_, inplace=True)
df.head()
# Out:
#              id tratamento  tempo dose   composto     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ## 2. Plotando gráficos usando Seaborn

# %%
len(df['g0'].unique())
# Out:
# 14367

# %%
# pegando apenas os 5 compostos mais frequêntes
top_compostos = df['composto'].value_counts().index[:5]
top_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
#filtra apenas os 5 compostos 
df.query('composto in @top_compostos')
# Out:
#                  id    tratamento  tempo dose   composto     g-0     g-1  \
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# 16     id_002fb9c19     com_droga     48   D1  87d714366  8.7380  0.1914
# 25     id_0054388ec  com_controle     48   D1  cacb2b860 -0.6696 -0.2718
# 38     id_0079af0fb  com_controle     24   D1  cacb2b860 -0.1636 -1.8230
# 40     id_007bfbb91  com_controle     24   D2  cacb2b860 -1.3200 -1.7340
# ...             ...           ...    ...  ...        ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  cacb2b860  0.6008  0.2781
# 23802  id_fff3976bd     com_droga     24   D1  87d714366  3.2890  2.1270
# 23805  id_fff6df1c5     com_droga     48   D2  5628cb3ee  1.7380 -1.2900
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
sns.set()
plt.figure(figsize=(12,8))
ax = sns.countplot(data = df.query('composto in @top_compostos'), x = 'composto')
ax.set_title('Top 5 compostos', fontsize=20)
ax.set_ylabel('Quantidade', fontsize=14)
ax.set_xlabel('Compostos', fontsize=14)
plt.show()

# %% [markdown]
# ## 3. Plotando histogramas

# %% [markdown]
# O parâmetro ``bins`` define quantos 'blocos' o gráfico será partido.

# %%
df['g0'].hist()
# Out:
# <AxesSubplot:>

# %%
df['g0'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Análisando colunas específicas

# %%
df.describe()
# Out:
#               tempo            g0            g1            g2            g3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                  g4            g5            g6            g7            g8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %% [markdown]
# ``std`` = desvio padrão

# %% [markdown]
# Uma estratégia mais direta em que não precisaremos escrever a lista gene a gene, é o uso da função ```loc[]``` do Pandas.
# Como argumentos, passamos primeiramente o ```:```, os dois pontos faz com que o ```loc[]```retorne todos os elementos de uma determinada coluna, isso é importante quando não sabemos qual a quantidade de linhas de um dataframe. E, o segundo elemento, passamos as colunas que são de nosso interesse. No caso, queremos que a função nos retorne todos os elementos das colunas ```g-0```até ```g-771```.
# E, por fim, podemos declarar a nossa função de interesse a partir deste filtro realizado nos dados, o ```describe()```.

# %%
df.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1            g2            g3            g4  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.248366     -0.095684      0.152253      0.081971      0.057347
# std        1.393399      0.812363      1.035731      0.950012      1.032091
# min       -5.513000     -5.737000     -9.104000     -5.998000     -6.369000
# 25%       -0.473075     -0.562200     -0.437750     -0.429575     -0.470925
# 50%       -0.008850     -0.046600      0.075200      0.008050     -0.026900
# 75%        0.525700      0.403075      0.663925      0.463400      0.465375
# max       10.000000      5.039000      8.257000     10.000000     10.000000
#
#                  g5            g6            g7            g8            g9  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      -0.138836      0.035961     -0.202651     -0.190083      0.119905
# ...

# %% [markdown]
# ``.T`` faz a matriz transposta.

# %%
df.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Plotando um Boxplot

# %%
sns.boxplot(x='g0' , data=df)
# Out:
# <AxesSubplot:xlabel='g0'>

# %% [markdown]
# sns.boxplot(x='g0',y='tratamento' , data=df)

# %% [markdown]
# ## 6. Plotando 2 gráficos, lado a lado

# %%
label = ['com_droga', 'com_controle']
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.pie(df['tratamento'].value_counts())
plt.legend(labels=label, loc='best')
plt.subplot(122)
df['tempo'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Desafios

# %% [markdown]
# ### Desafio 01: Ordenar o gráfico countplot

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(data = df.query('composto in @top_compostos'), 
                   x = 'composto', 
                   order = df['composto'].value_counts().index[:5])
ax.set_title('Top 5 compostos', fontsize=20)
plt.show()

# %% [markdown]
# ### Desafio 02: Melhorar a visualização alterando tamanho da fonte...

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(data = df.query('composto in @top_compostos'), 
                   y = 'composto', 
                   order = df['composto'].value_counts().index[:5],
                   palette="Set2")

ax.set_title('Top 5 compostos', fontsize=22)
ax.set_xlabel('Quantidade', fontsize=15)
ax.set_ylabel('Compostos', fontsize=15)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()

# %% [markdown]
# ### Desafio 03: Plotar os histogramas com seaborn

# %%
plt.figure(figsize=(10,8))
ax = sns.histplot(data=df, x='g0')
ax.set_title('Histograma do g-0', fontsize=20)
ax.set_xlabel('g0', fontsize=14)
ax.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,8))
dados = df.loc[:,'g0':'g771']
ax = sns.histplot(data=dados, x=dados.describe().T['mean'])
ax.set_title('Histograma das médias', fontsize=20)
ax.set_xlabel('Médias', fontsize=14)
ax.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %% [markdown]
# ### Desafio 04: Estudar sobre as estatíticas retornadas no .describe()

# %%
df['g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %% [markdown]
# <b>count:</b> é a contagem da ``ocorrência`` de certo valor.
#
# <b>mean:</b> em estatística, média é definida como o valor que demonstra a ``concentração dos dados`` de uma distribuição, como o ponto de ``equilíbrio`` das frequências em um histograma
#
# <b>std:</b> O ``desvio padrão`` é uma medida que expressa o grau de dispersão de um conjunto de dados. Ou seja, o desvio padrão indica o quanto um conjunto de dados é ``uniforme``. Quanto mais ``próximo de 0`` for o desvio padrão, mais ``homogêneo`` são os dados.
# O desvio padrão é uma das medidas estatísticas mais comumente usadas para ``demonstrar a variabilidade`` dos dados. É uma medida que estima o grau em que o valor de determinada variável se ``desvia da média``. Matematicamente a raiz quadrada da variância é o desvio padrão.
#
# <b>min e max:</b> maior valor e menor valor do conjunto de dados.
#
# <b>25%, 50%, 75%:</b> It describes the distribution of your data: 50 should be a value that describes „the middle“ of the data, also known as median. 25, 75 is the border of the upper/lower quarter of the data. You can get an idea of how skew your data is. Note that the mean is higher than the median, which means your data is right
# <a href="https://en.m.wikipedia.org/wiki/Skewness">skewed</a>.
#
# Fonte: <a href="https://datascience.stackexchange.com/questions/52613/what-does-pandas-describe-percentiles-values-tell-about-our-data#:~:text=It%20describes%20the%20distribution%20of,lower%20quarter%20of%20the%20data">stackoverflow</a>

# %% [markdown]
# ### Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# ### Desafio 06: Fazer outras análises com o boxplot e até com o histograma.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(12,6))

sns.histplot(data=df, x='g0', bins=50, ax = ax1)
ax1.set_title('Histograma g-0', fontsize=20)
ax1.set_xlabel('gene', fontsize=14)
ax1.set_ylabel('Quantidade', fontsize=14)

sns.histplot(data=df, x='g1', bins=50, ax = ax2)
ax2.set_title('Histograma g-1', fontsize=20)
ax2.set_xlabel('gene', fontsize=14)
ax2.set_ylabel('Quantidade', fontsize=14)

sns.histplot(data=df, x='g2', bins=50, ax = ax3)
ax3.set_title('Histograma g-2', fontsize=20)
ax3.set_xlabel('gene', fontsize=14)
ax3.set_ylabel('Quantidade', fontsize=14)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,6)) 

sns.boxplot(x='tratamento', y='c0', data=df, palette='Reds', ax=ax1)
sns.boxplot(x='tratamento', y='g0', data=df, palette='Blues', ax=ax2)

plt.show()

# %% [markdown]
# ### Desafio 07: Resumo do que você aprendeu com os dados
